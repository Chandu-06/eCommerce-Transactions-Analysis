# %% [markdown]
# **Task 1: EDA & Business Insights**
#
# Load the Data: Begin by loading all the CSV files into Pandas DataFrames and checking for missing values, duplicates, and basic info about the data.
#
# Visualizations:
# Customer Distribution by Region: Visualize how customers are distributed by their geographical region.
#
# Product Price Distribution: Visualize the price distribution of the products.
#
# Top Products by Sales Value: Display the products with the highest sales by total value.
#
# Business Insights: Use the visualizations to derive meaningful insights about customer demographics, product popularity, sales trends, price sensitivity, and customer activity.

# %% [markdown]
# **Load the datasets**

# %%
import pandas as pd

customers = pd.read_csv('/content/Customers.csv')
products = pd.read_csv('/content/Products.csv')
transactions = pd.read_csv('/content/Transactions.csv')

# %% [markdown]
# **Check for missing values and basic info**

# %%
print(customers.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    200 non-null    object
#  1   CustomerName  200 non-null    object
#  2   Region        200 non-null    object
#  3   SignupDate    200 non-null    object
# dtypes: object(4)
# memory usage: 6.4+ KB
# None

# %%
print(products.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    100 non-null    object
#  1   ProductName  100 non-null    object
#  2   Category     100 non-null    object
#  3   Price        100 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 3.3+ KB
# None

# %%
print(transactions.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    1000 non-null   object
#  1   CustomerID       1000 non-null   object
#  2   ProductID        1000 non-null   object
#  3   TransactionDate  1000 non-null   object
#  4   Quantity         1000 non-null   int64
#  5   TotalValue       1000 non-null   float64
#  6   Price            1000 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 54.8+ KB
# None

# %% [markdown]
# **Preview the data**

# %%
print(customers.head())
# Out:
#   CustomerID        CustomerName         Region  SignupDate
# 0      C0001    Lawrence Carroll  South America  10-07-2022
# 1      C0002      Elizabeth Lutz           Asia  13-02-2022
# 2      C0003      Michael Rivera  South America  07-03-2024
# 3      C0004  Kathleen Rodriguez  South America  09-10-2022
# 4      C0005         Laura Weber           Asia  15-08-2022

# %%
print(products.head())
# Out:
#   ProductID              ProductName     Category   Price
# 0      P001     ActiveWear Biography        Books  169.30
# 1      P002    ActiveWear Smartwatch  Electronics  346.30
# 2      P003  ComfortLiving Biography        Books   44.12
# 3      P004            BookWorld Rug   Home Decor   95.69
# 4      P005          TechPro T-Shirt     Clothing  429.31

# %%
print(transactions.head())
# Out:
#   TransactionID CustomerID ProductID   TransactionDate  Quantity  TotalValue  \
# 0        T00001      C0199      P067  25-08-2024 12:38         1      300.68
# 1        T00112      C0146      P067  27-05-2024 22:23         1      300.68
# 2        T00166      C0127      P067  25-04-2024 07:38         1      300.68
# 3        T00272      C0087      P067  26-03-2024 22:55         2      601.36
# 4        T00363      C0070      P067  21-03-2024 15:10         3      902.04
#
#     Price
# 0  300.68
# 1  300.68
# 2  300.68
# 3  300.68
# 4  300.68

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of customer regions
sns.countplot(data=customers, x='Region')
plt.title('Customer Distribution by Region')
plt.show()

# %%
# Distribution of product prices
sns.histplot(products['Price'], bins=20, kde=True)
plt.title('Product Price Distribution')
plt.show()

# %%
# Total sales per product
product_sales = transactions.groupby('ProductID')['TotalValue'].sum().sort_values(ascending=False)
top_products = product_sales.head(10)

# Plot the top 10 products by sales value
top_products.plot(kind='bar')
plt.title('Top 10 Products by Sales Value')
plt.xlabel('Product ID')
plt.ylabel('Total Sales Value')
plt.show()
